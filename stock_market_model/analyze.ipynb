# %%
import matplotlib
# %matplotlib inline
import analyze

# %% [markdown]
# Ниже некоторые графики построенные при симуляции при A=1.8.

# %%
analyze.analyze(1)

# %% [markdown]
# Ниже некоторые графики построенные при симуляции при A=2.1.

# %%
analyze.analyze(2)

# %% [markdown]
# Ниже некоторые графики построенные при симуляции при A=2.5.

# %%
analyze.analyze(3)
